# %%
import pandas as pd

# %%
df =pd.read_csv(r'C:\Users\mager\Downloads\archive (1)\loans.csv',parse_dates = ['start_date'])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   loan_id        22000 non-null  int64
#  1   customer_id    22000 non-null  int64
#  2   branch_id      22000 non-null  int64
#  3   loan_type      22000 non-null  object
#  4   loan_amount    22000 non-null  float64
#  5   interest_rate  22000 non-null  float64
#  6   term_months    22000 non-null  int64
#  7   start_date     22000 non-null  object
#  8   status         22000 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.5+ MB
# None

# %%
df['lon_type'] = df['loan_type'].str.strip()
df['status'] = df['status'].str.strip()

# %%
df['start_year'] = df['start_date'].dt.year
df['start_month'] = df['start_date'].dt.month
df['start_days'] = df['start_date'].dt.day

# %%
df.to_csv('loans.csv',index=False)
