# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\mager\Downloads\archive (1)\transactions.csv',parse_dates = ['txn_date'])

# %%
print(df.head())

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 7 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   transaction_id     int64
#  1   account_id         int64
#  2   txn_date           datetime64[ns]
#  3   txn_type           object
#  4   amount             float64
#  5   channel            object
#  6   merchant_category  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 106.8+ MB
# None

# %%
df['txn_type'] = df['txn_type'].astype(str).str.strip
df['channel'] = df['channel'].astype(str).str.strip
df['merchant_category'] = df['merchant_category'].astype(str).str.strip

# %%
df['txn_years'] = df['txn_date'].dt.year
df['txn_months'] = df['txn_date'].dt.month
df['txn_days'] = df['txn_date'].dt.day

# %%
df.to_csv('transactions.csv',index =False)
