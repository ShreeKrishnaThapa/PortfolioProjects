# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\mager\Downloads\archive (1)\employees.csv',parse_dates = ['hire_date'])

# %%
print(df.head())
# Out:
#    employee_id               name  branch_id                  role  hire_date  \
# 0            1  Richard Rodriguez         30      Customer Service 2016-11-09
# 1            2   Robert Rodriguez        136  Relationship Manager 2010-08-04
# 2            3    Arjun Rodriguez         35      Customer Service 2020-02-12
# 3            4        Arjun Singh        146          Loan Officer 2022-02-11
# 4            5       Robert Joshi         29      Customer Service 2010-05-09
#
#    salary
# 0   62479
# 1   50855
# 2   94948
# 3   40756
# 4  155016

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   employee_id  1800 non-null   int64
#  1   name         1800 non-null   object
#  2   branch_id    1800 non-null   int64
#  3   role         1800 non-null   object
#  4   hire_date    1800 non-null   datetime64[ns]
#  5   salary       1800 non-null   int64
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 84.5+ KB
# None

# %%
df['hire_date'] = pd.to_datetime(df['hire_date'])

# %%
df['name']  = df['name'].str.strip()
df['name'] =df['role'].str.strip()

# %%
df['name'] =df['name'].str.title()
df['role'] = df['role'].str.title()

# %%
df['hire_year'] = df['hire_date'].dt.year
df['hire_month'] = df['hire_date'].dt.month 
df['hire_day'] = df['hire_date'].dt.day

# %%
df.to_csv("employeed.csv", index=False)
